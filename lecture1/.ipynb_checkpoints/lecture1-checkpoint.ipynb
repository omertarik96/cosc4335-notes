# %% [markdown]
#  # Lecture 1 - June 3, 2019
#
#  ## Intro to Course, Data Science Capstone
#
#  - CS Data Science Capstone => COSC 3337(COSC 4335) + COSC 4337(Data Science II)(Starting from Spring 2020)
#  - Every Friday there is an exam
#      - Each week only consists of that week's content, there will be no final exam, only 4 exams
#
#
#  ## Books
#
#  - [Statistic book](https://cnx.org/contents/tWu56V64@33.122:-mZCQZc7@5/Introduction) -> Chapter 2,3,13 needed
#
#
#  ## Course Schedule
#
# ### 1. Week 1 (June 3 - June 7)
# - What is data science
# - Review statistics
# - Python
# - Linear regression
# - exploratory data analysis
# - decision tree
# - **Exam1 June 7**
#
# ### 2. Week 2 (June 10- June 14)
# - Naïve Bayes
# - Metrics
# - model overfitting
# - storytelling
# - **Exam 2 June 14**
#
# ### 3. Week 3 (June 17- June 21)
# - SVM-DBSCAN-kmeans
# - Cluster Analysis
# - **Exam 3 June 21**
#
# ### 4. Week 4 (June 24- June 28)
# - Hierarchical clustering
# - apriori
# - association rules
# - **Exam 4 June 28**

# %% [markdown]
# ## What is Data Science
#
# Data science for service change.
#
# **Data science** is applying advanced statistical tools to existing data to generate new insights.
# **Service change** is converting new data insights into changes to business processes
#
# **Purpose of data science**: Get more efficient and effective use of resources
#
# #### What complements data science
#
# 1. Approach
# 2. Process
# 3. Outcome
#
# **Missing data imputation**: What will be do if data is missing
#
# *Service Issue -> Data Science -> Service Change*

# %% [markdown]
# ## Statistics Review
#
# **Descriptive Statistics**: Describe, explain and understand the data
#
# **Mean**: Average
#
# **Median**: One in the middle
#
# **Mode**: Most occurred one
#
# **Interquartile Range**: Range between 25th percentile and the 75th percentile. See the population around the middle
#
# **Variance**: A measure of the spread of the recorded values. Larger the variance data spreads larger area.
#
# **Deviation**: How far from the mean
#
# **SS**: Sum of squares
#
# **Standart Deviation**
#
#
# **Box Plots**: (Check the slides from descriptive statistics). **EXAM**

# %% [markdown]
# ## Exam 1
#
# This will be about data cleaning.
#
# ## Data Cleaning Steps
#
# 1. Fill in the missing values
# 2. Identify outliners and smooth out noisy data
# 3. Correct inconsistent data
# 4. Resolve redundancy caused by data integration
#
# ## Correlation Analysis
#
# (Pearson's product moment coefficient)
#
# (x^2, chi-square analysis)
#
# ## Normalization
#
# 1. Min-max
# 2. z-score
# 3. normalization by decimal scaling
#
#
# ## Standartization
